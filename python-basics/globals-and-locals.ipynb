# %%
name = "Global Ranga"
def greet():
    #name = "hello"
    def hello():
        #name =  "Local Ranga"
        print(name)
    hello()

greet()
# Out:
# Global Ranga

# %%
name = "Global Ranga"
def greet():
    global name
    name = "hello"
    def hello():
        global name
        name =  "Local Ranga"
        print(name)
    hello()

greet()
# Out:
# Local Ranga

# %%
name
# Out:
# 'Local Ranga'
