# %%
import os

dirName = os.path.join(os.getcwd(), 'package')

os.makedirs(dirName, exist_ok=True )

os.listdir(dirName)
# Out:
# []

# %%
#### Exceptions ####
try:
    n = int(input('Enter a number: '))
    a = 1/n
except NameError as ex:
    print(f'Variable is not defined. Error: {ex}')
except Exception as e:
    print(f'Unknown error: Error: {e}')
else:
    print(f'Operation successful with {a}')
# Out:
# Operation successful with 0.1
